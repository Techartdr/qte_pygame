# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../assets/scores.csv")

first_col = df["id"]
second_col = df["Pseudo"]
third_col = df["Score"]
fourth_col = df["Difficulté"]
time_col = df["Temps"]

df['index_unique'] = range(len(df))

df.head()
# Out:
#            id Pseudo  Score  Difficulté       Temps  index_unique
# 0  1731687152  Driss     57          22  220.188016             0
# 1  1731689648   Aure     34          16  156.754748             1
# 2  1731689809   Aure     34          16  156.793914             2

# %%
x = df['index_unique']
labels = df['Pseudo']

y = df['Score']
y_label = "Score"
title = "Graphique des Scores des Joueurs"

# %%
plt.bar(x, y, color="green")
plt.title(f"{title} (Barres)")
# Out:
# Text(0.5, 1.0, 'Graphique des Scores des Joueurs (Barres)')

# %%
plt.plot(x, y, color="green")
plt.title(f"{title} (Lignes)")
# Out:
# Text(0.5, 1.0, 'Graphique des Scores des Joueurs (Lignes)')

# %%
plt.scatter(x, y, color="green")
plt.title(f"{title} (Points)")
# Out:
# Text(0.5, 1.0, 'Graphique des Scores des Joueurs (Points)')

# %%
y = df['Temps']
y_label = "Temps de Jeu (secondes)"
title = "Graphique des Temps de Jeu des Joueurs"

# %%
plt.bar(x, y, color="green")
plt.title(f"{title} (Barres)")
# Out:
# Text(0.5, 1.0, 'Graphique des Scores des Joueurs (Barres)')

# %%
plt.plot(x, y, color="green")
plt.title(f"{title} (Lignes)")
# Out:
# Text(0.5, 1.0, 'Graphique des Scores des Joueurs (Lignes)')

# %%
plt.scatter(x, y, color="green")
plt.title(f"{title} (Points)")
# Out:
# Text(0.5, 1.0, 'Graphique des Scores des Joueurs (Points)')
